# %% [markdown]
# ## Задание
#
# Необходимо собрать информацию о вакансиях на вводимую должность (используем input или через аргументы) с сайта superjob.ru
# и hh.ru. Приложение должно анализировать несколько страниц сайта(также вводим через input или аргументы). Получившийся список должен содержать в себе минимум:
#
# *Наименование вакансии
#
# *Предлагаемую зарплату (отдельно мин. отдельно макс. и отдельно валюту)
#
# *Ссылку на саму вакансию
#
# *Сайт откуда собрана вакансия
#
# По своему желанию можно добавить еще работодателя и расположение.
# Данная структура должна быть одинаковая для вакансий с обоих сайтов.
# Общий результат можно вывести с помощью dataFrame через pandas.

# %%
import requests
import json
from pprint import pprint
from bs4 import BeautifulSoup as bs
from lxml import html
import pandas as pd
import re

# %%
request = 'machine learning'

# %%
page = 0
max_page = 0

# %%
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.163 Safari/537.36'}

# %%
vacancy_link_data = []
vacancy_name_data = []
vacancy_minsalary_data = []
vacancy_maxsalary_data = []
vacancy_currancy_data = []
vacancy_salary_data = []

# %%
while max_page != 40:
    link = f'https://hh.ru/search/vacancy?area=1&st=searchVacancy&text={request}&page={page}'
    response = requests.get(link, headers=header).text
    soup = bs(response,'lxml')
    vacancy_block = soup.find_all('div',{'class':'vacancy-serp'})[0]
    vacancy_list = vacancy_block.find_all('div',{'class':'vacancy-serp-item'})
    page += 1
    max_page += 1
    for vacancy in range(len(vacancy_list)):
        name1 = vacancy_block.find_all('span',{'class':'g-user-content'})[vacancy]
        name2 = name1.findChild()
        vacancy_name = name2.getText()
        vacancy_name_data.append(vacancy_name)
        vacancy_data={}
        vacancy_link1 = vacancy_block.find_all('span',{'class':'g-user-content'})[vacancy]
        vacancy_link = vacancy_link1.find('a')['href']
        vacancy_link_data.append(vacancy_link)
        salary1 = vacancy_block.find_all('div',{'class':'vacancy-serp-item__sidebar'})[vacancy]
        salary2 = str(salary1.findChild(recursive=False))
        salary3 = re.sub(r'\<[^>]*\>', '', salary2)

        if salary3 == None:
            salary = 0
        else:
            salary = salary3
            
        max_salary = 0
        min_salary = 0
        currency_salary = "NaN"

        if len(salary) > 1:
            salary_split = salary.split(" ")

            if salary_split[0] == 'от':
                max_salary = None
                min_salary = int(re.sub('\D',"",salary_split[1]))
                currency_salary = salary_split[2].replace(".","")  

            elif salary_split[0] == 'до':
                min_salary = None
                max_salary = int(re.sub('\D',"",salary_split[1]))
                currency_salary = salary_split[2].replace(".","")              

            else:
                salary2split = salary_split[0].split("-")
                if len(salary2split) > 1:
                    min_salary = int(re.sub('\D',"",salary2split[0]))
                    max_salary = int(re.sub('\D',"",salary2split[1]))
                    currency_salary = salary_split[1].replace(".","")   

        vacancy_minsalary_data.append(min_salary)
        vacancy_maxsalary_data.append(max_salary)
        vacancy_currancy_data.append(currency_salary)            
            
            
        vacancy_salary_data.append(salary)

# %%
len(vacancy_salary_data)
# Out:
# 248

# %%
len(vacancy_list)
# Out:
# 0

# %%
data = {'Vacancy Name': vacancy_name_data, 'Link': vacancy_link_data, 'Min_salary': vacancy_minsalary_data, 'Max_salary': vacancy_maxsalary_data, 'Currancy': vacancy_currancy_data,'Source': 'hh'}
df = pd.DataFrame(data)

# %%
df
# Out:
#                                           Vacancy Name  \
# 0    Специалист: Computer Vision & Machine Learning...
# 1    Начинающий специалист: Computer Vision & Machi...
# 2                            Machine Learning Engineer
# 3    Разработчик C++ (Computer Graphics / Computer ...
# 4                                Junior Data Scientist
# 5                                       Data Scientist
# 6    Менеджер по исследованию больших данных (Data ...
# 7                          Data Scientist in Oil & Gas
# 8           Data Scientist / Machine Learning Engineer
# 9    3D Machine Learning Research and Development E...
# 10   Head of Data Science Department (в Украину, Од...
# 11   Специалист по машинному обучению ( Data scient...
# 12            Аналитик-математик / Junior Data Analyst
# 13        Аналитик данных (Data Scientist) разработчик
# 14   C++/Deep Learning/ Machine Learning Developer ...
# 15                             ML разработчик (Python)
# 16                Аналитик данных HR (HR Data analyst)
# 17   Senior Data Scientist в NLP лабораторию СКБ Ко...
# 18                                   Data Analyst (BI)
# 19                               Data Science Director
# 20                         Data Scientist (AI systems)
# 21                               Senior Data Scientist
# 22                      Data Scientist (Delivery Club)
# 23                             Data scientist (middle)
# 24                    Data Scientist (Computer Vision)
# 25                      Quantitative Software Engineer
# 26                                 Lead Data Scientist
# 27     Data Scientist / Senior Data Scientist (Python)
# 28   Старший специалист по машинному обучению / Dat...
# 29                               Аналитик Data Science
# ..                                                 ...
# 218                             ML Researcher (AI Lab)
# 219                     Scheduling Algorithm Scientist
# 220      Главный менеджер/ Инженер данных (Data Miner)
# 221             Ведущий разработчик-исследователь (AI)
# 222      Менеджер по анализу больших данных (Big data)
# 223       Программист Python/Стажер-программист Python
# 224                     Digital Marketing Data Analyst
# 225             Старший разработчик-исследователь (AI)
# 226                               Senior C++ developer
# 227                Менеджер проектов / Project manager
# 228       Разработчик машинного обучения (Видеопроект)
# 229                             Junior PHP разработчик
# 230                             Scala Senior Developer
# 231                  Frontend-разработчик в DS-команду
# 232      Аналитик (проектирование баз данных клиентов)
# 233                      Ведущий консультант Oracle BI
# 234                                    Scala Developer
# 235                 Scala разработчик (м. Китай-город)
# 236                         Storage Algorithm Engineer
# 237                 Technical Director of SaaS product
# 238       Researcher of Network Algorithm and Modeling
# 239                              Разработчик IT кейсов
# 240                           Аналитик/General Analyst
# 241                      Архитектор цифровой платформы
# 242                     Руководитель отдела разработки
# 243                                Backend-разработчик
# 244           Менеджер по продажам и развитию it-услуг
# 245  Software Development Engineer in Test ( Python...
# 246                                       SMM-менеджер
# 247                                        IT Аналитик
#
#                                                   Link  Min_salary  \
# 0    https://hh.ru/vacancy/30255734?query=machine%2...    200000.0
# 1    https://hh.ru/vacancy/34148970?query=machine%2...         0.0
# 2    https://hh.ru/vacancy/36648473?query=machine%2...         0.0
# 3    https://hh.ru/vacancy/36752503?query=machine%2...         0.0
# 234  https://hh.ru/vacancy/36020230?query=machine%2...         0.0
# 235  https://hh.ru/vacancy/36416210?query=machine%2...         0.0
# 236  https://hh.ru/vacancy/36414353?query=machine%2...         0.0
# 237  https://hh.ru/vacancy/36462636?query=machine%2...         0.0
# 238  https://hh.ru/vacancy/36372223?query=machine%2...         0.0
# 239  https://hh.ru/vacancy/36341466?query=machine%2...         0.0
# 240  https://hh.ru/vacancy/36341464?query=machine%2...         0.0
# 241  https://hh.ru/vacancy/35654540?query=machine%2...         0.0
# 242  https://hh.ru/vacancy/36422204?query=machine%2...         0.0
# 243  https://hh.ru/vacancy/36400848?query=machine%2...         0.0
# 244  https://hh.ru/vacancy/36431622?query=machine%2...         0.0
# 245  https://hh.ru/vacancy/36415144?query=machine%2...         0.0
# 246  https://hh.ru/vacancy/36415376?query=machine%2...     60000.0
# 247  https://hh.ru/vacancy/35085132?query=machine%2...         0.0
#
#      Max_salary Currancy Source
# 0           NaN      руб     hh
# 1           0.0      NaN     hh
# 2           0.0      NaN     hh
# 3           0.0      NaN     hh
# 4      180000.0      руб     hh
# 5           0.0      NaN     hh
# 6           NaN      руб     hh
# 7           0.0      NaN     hh
# 8           0.0      NaN     hh
# 9           0.0      NaN     hh
# 10          0.0      NaN     hh
# 11          0.0      NaN     hh
# 12          0.0      NaN     hh
# 13          0.0      NaN     hh
# 14          0.0      NaN     hh
# 15          0.0      NaN     hh
# 16          0.0      NaN     hh
# 17          0.0      NaN     hh
# 18          0.0      NaN     hh
# 19          0.0      NaN     hh
# 20          0.0      NaN     hh
# 21          0.0      NaN     hh
# 22          0.0      NaN     hh
# 23          0.0      NaN     hh
# 24          0.0      NaN     hh
# 25          0.0      NaN     hh
# 26          0.0      NaN     hh
# 27          0.0      NaN     hh
# 28          0.0      NaN     hh
# 29          0.0      NaN     hh
# ..          ...      ...    ...
# 218         0.0      NaN     hh
# 219         0.0      NaN     hh
# 220         0.0      NaN     hh
# 221         0.0      NaN     hh
# 222         0.0      NaN     hh
# 223         0.0      NaN     hh
# 224    130000.0      руб     hh
# 225         0.0      NaN     hh
# 226         0.0      NaN     hh
# 227         0.0      NaN     hh
# 228         0.0      NaN     hh
# 229         0.0      NaN     hh
# 230         0.0      NaN     hh
# 231         0.0      NaN     hh
# 232         0.0      NaN     hh
# 233         0.0      NaN     hh
# 234         0.0      NaN     hh
# 235         0.0      NaN     hh
# 236         0.0      NaN     hh
# 237         0.0      NaN     hh
# 238         0.0      NaN     hh
# 239         0.0      NaN     hh
# 240         0.0      NaN     hh
# 241         0.0      NaN     hh
# 242         0.0      NaN     hh
# 243         0.0      NaN     hh
# 244         0.0      NaN     hh
# 245         0.0      NaN     hh
# 246    150000.0      руб     hh
# 247         0.0      NaN     hh
#
# [248 rows x 6 columns]

# %%
df.to_csv('hh_vacancies.csv', index=False)
